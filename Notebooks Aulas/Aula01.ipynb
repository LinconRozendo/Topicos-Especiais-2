# %% [markdown]
# **Exercícios Slide Aula 01 (pag 23):**

# %% [markdown]
# Exercícios:
# 1) Escreva um programa que calcule o faturamento de um representante comercial que recebe RS 500,00 fixos e 6% de comissão sobre as vendas do mês. Considere que ele fechou o mês com um valor de RS 12.398,00 em vendas. Exiba o resultado com duas casas decimais.

# %%
fixo = 500
vendas = 12398
taxa = 0.06

resultado = fixo + (vendas * taxa)
round(resultado, 2)
# Out:
# 1243.88

# %% [markdown]
# Exercícios:
# 2) Reescreva o programa anterior alterando-o de modo que as vendas do mês sejam lidas do teclado

# %%
vendas = float(input("Digite o valor da(s) venda(s): "))

resultado = fixo + (vendas * taxa)
round(resultado, 2)
# Out:
# Digite o valor da(s) venda(s): 12398
# 1243.88

# %% [markdown]
# **Exercícios Recomendados do Livro (Pag 47 e 48):**

# %% [markdown]
# 1. Faça X = 0.0 e Y = 18. Verifique o tipo de dado que o Python atribuiu a cada um. Faça Z = X + Y e verifique o resultado calculado e armazenado em Z. Verifique com qual tipo de dado foi criado o objeto Z.

# %%
X = 0.0
Y = 18

print(type(X))
print(type(Y))

Z = X + Y

print(Z)
print(type(Z))
# Out:
# <class 'float'>
# <class 'int'>
# 18.0
# <class 'float'>

# %% [markdown]
# 2. Atribua um valor qualquer a um objeto a (minúsculo). Utilize o comando *type* ou o comando print com o objeto A (maiúsculo). Relate o que aconteceu.

# %%
a = 'teste'

print(type(A))

#vai dar erro -_-
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-21f280890a82> in <module>()
#       1 a = 'teste'
#       2
# ----> 3 print(type(A))
#       4
#       5 #vai dar erro -_-
#
# NameError: name 'A' is not defined

# %% [markdown]
# Resposta: como a variável 'a' (minúscula) está armazenada na memória com um valor e a variável A (maiúscula) não está. É impossível chamar a variável A sem obter um erro.

# %% [markdown]
# 3. No IDLE, faça A = "Questão 3", B = 25 e C = 3.9. Utilize o comando *type* para verificar qual é o tipo de dados dos objetos A, B e C.

# %%
A = "Questão 3"
B = 25
C = 3.9

print(type(A))
print(type(B))
print(type(C))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# 4. Reproduza em um programa todos os casos de operações aritméticas do Quadro 2.1, para A = 14 e B = 5, e compare os valores obtidos por você com os valores esperados constantes do quadro.

# %%
A = 14
B = 5

C = A + B
print('C = A + B -- Resultado esperado no quadro: {0} // Resultado do programa: {1}'.format(19, C))

C = A - B
print('C = A - B -- Resultado esperado no quadro: {0} // Resultado do programa: {1}'.format(9, C))

C = A * B
print('C = A * B -- Resultado esperado no quadro: {0} // Resultado do programa: {1}'.format(70, C))

C = A / B
print('C = A / B -- Resultado esperado no quadro: {0} // Resultado do programa: {1}'.format(2.8, C))

C = A // B
print('C = A // B -- Resultado esperado no quadro: {0} // Resultado do programa: {1}'.format(2, C))

C = A % B
print('C = A % B -- Resultado esperado no quadro: {0} // Resultado do programa: {1}'.format(4, C))

C = - A
print('C = A - B -- Resultado esperado no quadro: {0} // Resultado do programa: {1}'.format(-14, C))

C = A ** B
print('C = A ** B -- Resultado esperado no quadro: {0} // Resultado do programa: {1}'.format(537824, C))
# Out:
# C = A + B -- Resultado esperado no quadro: 19 // Resultado do programa: 19
# C = A - B -- Resultado esperado no quadro: 9 // Resultado do programa: 9
# C = A * B -- Resultado esperado no quadro: 70 // Resultado do programa: 70
# C = A / B -- Resultado esperado no quadro: 2.8 // Resultado do programa: 2.8
# C = A // B -- Resultado esperado no quadro: 2 // Resultado do programa: 2
# C = A % B -- Resultado esperado no quadro: 4 // Resultado do programa: 4
# C = A - B -- Resultado esperado no quadro: -14 // Resultado do programa: -14
# C = A ** B -- Resultado esperado no quadro: 537824 // Resultado do programa: 537824

# %% [markdown]
# 5. Escreva a sequência de comandos necessária para o cálculo da área de um triângulo de base 9 e altura 6.

# %%
base = 9
altura = 6

area = ( base * altura) / 2
area
# Out:
# 27.0

# %% [markdown]
# 6. Refaça o exercício 5 e alterando-o de modo que a base e altura do triângulo sejam lidas do teclado. Considere-as números reais.

# %%
base = float(input("Digite o valor da base: "))
altura = float(input("Digite o valor da altura: "))

area = ( base * altura) / 2
area
# Out:
# Digite o valor da base: 9
# Digite o valor da altura: 6
# 27.0

# %% [markdown]
# 7. Escreva a sequência de comandos para calcular o salário bruto de um profissional que ganha por hora, sabendo que ele ganha RS 14,25/h e trabalhou 163 horas normais e 20 horas extras (pagam o dobro).

# %%
hora = 14.25
horas_normais = 163
horas_extras = 20

salario = (hora * horas_normais) + ((hora * 2) * horas_extras)
salario
# Out:
# 2892.75

# %% [markdown]
# 8. Escreva em Python as seguintes expressôes aritméticas para as fórmulas a seguir e teste as quatro primeiras para os valores A = 4, B = 5, C = 1 e a última para os valores x1 = 1, y1 = 1, x2 = 4 e y2 = 5.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Para responder esse exercício é necessário importar a biblioteca 'math' em virtude da necessidade de calcular a raíz quadrada

# %%
import math

# %%
A = 4
B = 5
C = 1

R = (A + B) / 2
print("Resposta 8.a: ", R)

R = (-B + (math.sqrt( (B ** 2) - 4 * A * C))) / (2 * A)
print("Resposta 8.b: ", R)

R = (3 * A + 2 * B) / (A + B)
print("Resposta 8.c: ", R)

R = (7.6 * A - (math.pow(B, 1.7)))
print("Resposta 8.d: ", R)

x1 = 1
y1 = 1
x2 = 4
y2 = 5

R = math.sqrt( (math.pow((x1 - x2), 2)) + (math.pow((y1 - y2), 2)))
print("Resposta 8.e: ", R)
# Out:
# Resposta 8.a:  4.5
# Resposta 8.b:  -0.25
# Resposta 8.c:  2.4444444444444446
# Resposta 8.d:  14.974153431999758
# Resposta 8.e:  5.0

# %% [markdown]
# **math.pow é usado para elevar um número por outro número.**
#
# Exemplo: math.pow(3, 2)<br>
# Eleva 3 por 2, resultado em 9.

# %%
x1 = float(input('Digite as coordenadas do ponto 1 (x1): '))
y1 = float(input('Digite as coordenadas do ponto 1 (y1): '))

x2 = float(input('Digite as coordenadas do ponto 2 (x2): '))
y2 = float(input('Digite as coordenadas do ponto 2 (y2): '))

distancia = math.sqrt( (math.pow((x1 - x2), 2)) + (math.pow((y1 - y2), 2)))
round(distancia, 3)
# Out:
# Digite as coordenadas do ponto 1 (x1): 6.9
# Digite as coordenadas do ponto 1 (y1): 2
# Digite as coordenadas do ponto 2 (x2): 16
# Digite as coordenadas do ponto 2 (y2): -1.8
# 9.862

# %% [markdown]
# 10. Um vendedor ambulante vendeu os produtos indicados na tabela a seguir.<br>
# Informe quanto ele faturou com cada produto e quando ele faturou no total.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Todos os dados devem ser lidos do teclado, sendo que o nome do produto é string, a quantidade vendida é um número inteiro e a valor unitário é um número real.

# %%
produto = input('Digite o nome do produto: ')
quantidade = int(input("Digite a quantidade do produto: "))
valor = float(input('Digite o valor unitário do produto: '))

print('Faturou {0} com o produto {1}'.format((valor * quantidade), produto))

valor_total = valor * quantidade

produto = input('Digite o nome do produto: ')
quantidade = int(input("Digite a quantidade do produto: "))
valor = float(input('Digite o valor unitário do produto: '))

print('Faturou {0} com o produto {1}'.format((valor * quantidade), produto))

valor_total += valor * quantidade

produto = input('Digite o nome do produto: ')
quantidade = int(input("Digite a quantidade do produto: "))
valor = float(input('Digite o valor unitário do produto: '))

print('Faturou {0} com o produto {1}'.format((valor * quantidade), produto))

valor_total += valor * quantidade

print('Faturamento total: ', valor_total)
# Out:
# Digite o nome do produto: boneco malandrinho
# Digite a quantidade do produto: 17
# Digite o valor unitário do produto: 18.5
# Faturou 314.5 com o produto boneco malandrinho
# Digite o nome do produto: spinner pequeno
# Digite a quantidade do produto: 36
# Digite o valor unitário do produto: 12
# Faturou 432.0 com o produto spinner pequeno
# Digite o nome do produto: cubo mágico
# Digite a quantidade do produto: 7
# Digite o valor unitário do produto: 5.9
# Faturou 41.300000000000004 com o produto cubo mágico
# Faturamento total:  787.8

# %% [markdown]
# **Exercícios Slide Aula 01 (pag 32):**

# %% [markdown]
# 1) Faça um programa para calcular a média aritmética entre duas notas de um aluno e para mostrar a situação desse aluno, que pode ser aprovado se ele tiver média maior ou igual a 7,0 ou reprovado se a sua média for inferior a 7,0.

# %%
nota1 = float(input("Digite a sua primeiro nota: "))
nota2 = float(input("Digite a sua segunda nota: "))

media = (nota1 + nota2) / 2

if media >= 7:
  print('Você foi aprovado.\nSua média foi: ', media)
else:
  print('Você foi reprovado.\nSua média foi: ', media)
# Out:
# Digite a sua primeiro nota: 7
# Digite a sua segunda nota: 6.9
# Você foi reprovado.
# Sua média foi:  6.95

# %% [markdown]
# **Exercícios Recomendados do Livro (Pag 74, 75 e 76):**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1
A = 0
B = -3
print(A > B)

# 2
X = 3.7
print(X <= 10.0)

# 3
A = 9
B = 16
print(A - B >= 0)

# 4
A = 2
B = 4
N = 10
print(A * B < N)

# 5
A = 3
B = 9
C = 5
print(10 * A >= B * C)

#6
A = 3
B = 6
C = 5
print(10 * A >= B * C)

#7 
N = 7
print(N % 2 == 0)

#8
N = 8
print(N % 2 == 0)

#9
T = "MORANGO"
print( T == "BANANA")

#10
T = "MORANGO"
print( T > "BANANA")
# Out:
# True
# True
# False
# True
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#1
A = 10 
B = 15
C = 4
print(A < B and A < C)

#2
print(A < B or A < C)

#3
A = 1
B = 9
C = 0
print(A >= 0 and B == C)

#4
C = 9
print(A >= 0 and B == C)

#5
C = 0
print(A >= 0 or B == C)

#6
C = 9
print(A >= 0 or B == C)

#7
A = 0
B = 0 
C = 0
print(B != 0 and A != C)

#8
C = 25
print(B != 0 and A != C)

#9
C = 0
print(B != 0 or A != C)

#10
C = 25
print(B != 0 or A != C)
# Out:
# False
# True
# False
# True
# True
# True
# False
# False
# False
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#1
A = 10
B = 15
C = 4
print(A < B and A < C or C != 0)

#2
print(A < B and (A < C or C != 0))

#3
A = 1
B = 9
C = 0
print(not (A >= 0 and B == C))

#4
C = 9
print(not (A >= 0) and not (B == C))

#5
C = 0
print((A >= 0 or B == C) and B > A)

#6
A = -2
B = 0
C = 2
print(not (A <= B) or C > B)

#7
A = -2
B = 0
C = 2
print(not (A <= 0 or C > B))

#8
A = 0
B = 1
C = 0
print(A == 0 and B != 0 and C == 0)

#9
A = 5
B = 0
C = 0
print(A == 0 and B != 0 and C == 0)

#10
print(A == 0 or B != 0 or C == 0)
# Out:
# True
# True
# True
# False
# True
# True
# False
# True
# False
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numero = int(input("Digite um número inteiro: "))

if numero > 0:
  print('O número digitado é positivo.')
elif numero == 0:
  print('O número não é positivo, nem negativo.')
else:
    print('O número digitado é negativo.')
# Out:
# Digite um número inteiro: -1
# O número digitado é negativo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Um exercício que faz a pergunta e diz a resposta.

numero = int(input("Digite um número inteiro: "))

if numero % 2 == 0:
  print('O número digitado é par.')
else:
    print('O número digitado é ímpar.')
# Out:
# Digite um número inteiro: 0
# O número digitado é par.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numero1 = int(input("Digite um número inteiro: "))
numero2 = int(input("Digite outro número inteiro: "))

if numero1 > numero2:
  print('Maior número: {0}\nMenor número: {1}'.format(numero1, numero2))
elif numero1 == numero2:
  print('Os dois números digitados possuem o mesmo valor.')
else:
  print('Maior número: {0}\nMenor número: {1}'.format(numero2, numero1))
# Out:
# Digite um número inteiro: 1
# Digite outro número inteiro: 2
# Maior número: 2
# Menor número: 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
lado_menor1 = float(input("Digite o valor do primeiro lado menor: "))
lado_menor2 = float(input("Digite o valor do segundo lado menor: "))
lado_maior = float(input("Digite o valor do lado maior: "))

if (lado_menor1 + lado_menor2) > lado_maior:
  if lado_menor1 == lado_menor2 and lado_menor2 == lado_maior:
    print("Triângulo equilátero")
  elif (lado_menor1 == lado_menor2) or (lado_menor2 == lado_maior) or (lado_menor1 == lado_maior):
    print('Triângulo Isósceles')
  else:
    print('Triângulo Escaleno')
else:
  print('Não é um triângulo')
# Out:
# Digite o valor do primeiro lado menor: 1
# Digite o valor do segundo lado menor: 3
# Digite o valor do lado maior: 2
# Triângulo Escaleno

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nome = input('Digite o seu nome: ')
peso = float(input('Digite seu peso: '))

if peso < 65:
  categoria = 'Pena'
  print('O lutador {0} pesa {1} kg e se enquadra na categoria {2}'.format(nome, str(peso).replace('.',','), categoria))
elif peso >= 65 and peso < 72:
  categoria = 'Leve'
  print('O lutador {0} pesa {1} kg e se enquadra na categoria {2}'.format(nome, str(peso).replace('.',','), categoria))
elif peso >= 72 and peso < 79:
  categoria = 'Ligeiro'
  print('O lutador {0} pesa {1} kg e se enquadra na categoria {2}'.format(nome, str(peso).replace('.',','), categoria))
elif peso >= 79 and peso < 86:
  categoria = 'Meio-médio'
  print('O lutador {0} pesa {1} kg e se enquadra na categoria {2}'.format(nome, str(peso).replace('.',','), categoria))
elif peso >= 86 and peso < 93:
  categoria = 'Médio'
  print('O lutador {0} pesa {1} kg e se enquadra na categoria {2}'.format(nome, str(peso).replace('.',','), categoria))
elif peso >= 93 and peso < 100:
  categoria = 'Meio-pesado'
  print('O lutador {0} pesa {1} kg e se enquadra na categoria {2}'.format(nome, str(peso).replace('.',','), categoria))
else:
  categoria = 'Pesado'
  print('O lutador {0} pesa {1} kg e se enquadra na categoria {2}'.format(nome, str(peso).replace('.',','), categoria))
# Out:
# Digite o seu nome: Pepe Jordão
# Digite seu peso: 73.4
# O lutador Pepe Jordão pesa 73,4 kg e se enquadra na categoria Ligeiro

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
valor_hora = float(input('Digite o valor hora: '))
hora_normais = float(input('Digite a quantidade de horas normais trabalhadas: '))
hora_extras = float(input('Digite a quantidade de horas extras trabalhadas: '))

valor_recebido = (valor_hora * hora_normais) + ((valor_hora * 2) * hora_extras)

print('Você receberá nesse mês: ', valor_recebido)
# Out:
# Digite o valor hora: 10
# Digite a quantidade de horas normais trabalhadas: 10
# Digite a quantidade de horas extras trabalhadas: 2
# Você receberá nesse mês:  140.0

# %% [markdown]
# FIM!
