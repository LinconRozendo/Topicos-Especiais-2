# %% [markdown]
# # **Exercícios do Slide 'Aula_04'**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

x = np.arange(-5, 6, 0.1)

plt.plot(x, np.sin(x)+1, x, 2*x**3+1)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico')
# Out:
# Text(0.5, 1.0, 'Gráfico')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Gráfico de Barra

# %%
nomes = ['Carros', 'Motos', 'Bicicletas']
quantidades = [50, 100, 200]
plt.bar(nomes, quantidades)
plt.show()

# %% [markdown]
# # Gráfico de Pizza

# %%
nomes = ['Carros', 'Motos', 'Bicicletas']
quantidades = [10, 30, 20]
plt.pie(quantidades, labels = nomes, autopct = '%1f%%')
plt.show()

# %% [markdown]
# # Histograma

# %%
a = np.random.randint(1000, size = 100)
plt.hist(a, 5, rwidth = 0.4)
plt.show()

# %% [markdown]
# # **FIM!**
